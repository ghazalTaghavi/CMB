# %% [markdown]
# Patch

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd gdrive/MyDrive/
# Out:
# /content/gdrive/MyDrive

# %%
import numpy as np
cl = np.load('./cl_planck_lensed.npy')
ll = cl[:,0]
cl = cl[:,1]
# !pip install -q 'healpy==1.13.0'
'astropy==4.0'
import healpy
import healpy as hp
# Out:
#      |████████████████████████████████| 11.8 MB 5.2 MB/s

# %%
cmb_map = healpy.sphtfunc.synfast(cl, 2048)
# Out:
# /usr/local/lib/python3.7/dist-packages/healpy/sphtfunc.py:400: FutureChangeWarning: The order of the input cl's will change in a future release.
# Use new=True keyword to start using the new order.
# See documentation of healpy.synalm.
#   category=FutureChangeWarning,
# Sigma is 0.000000 arcmin (0.000000 rad)
# -> fwhm is 0.000000 arcmin

# %%
import healpy as hp
hp.mollview(cmb_map, cmap='jet')

# %%
# !pip install git+https://github.com/vafaei-ar/ccgpack.git
# Out:
# ...
#   Cloning https://github.com/vafaei-ar/ccgpack.git to /tmp/pip-req-build-gth3ttnh
#   Running command git clone -q https://github.com/vafaei-ar/ccgpack.git /tmp/pip-req-build-gth3ttnh
# ...
#   Created wheel for ccgpack: filename=ccgpack-0.1.0-cp37-cp37m-linux_x86_64.whl size=910079 sha256=555c0fabe20ecb0806a76251891705a982b36b0622739fb140a045fd41f2af89
#   Stored in directory: /tmp/pip-ephem-wheel-cache-08bwxnmu/wheels/12/6f/95/7ae57565d174cea0e92a0da0a36f289e045f46ef2173da656b
# Successfully built ccgpack
# ...

# %%
from ccgpack import sky2patch
patch = sky2patch(cmb_map, npatch=8)
print(patch.shape)
# Out:
# (768, 256, 256)

# %%
import matplotlib.pyplot as plt
plt.imshow(patch[29], cmap='jet')
plt.show()
