# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd gdrive/MyDrive/
# Out:
# /content/gdrive/MyDrive

# %%
import numpy as np
cl = np.load('./cl_planck_lensed.npy')
ll = cl[:,0]
cl = cl[:,1]

# %%
# !pip install -q 'healpy==1.13.0'
'astropy==4.0'
# Out:
# 'astropy==4.0'

# %%
import healpy
healpy.sphtfunc.synfast(cl, 2048)
# Out:
# /usr/local/lib/python3.7/dist-packages/healpy/sphtfunc.py:400: FutureChangeWarning: The order of the input cl's will change in a future release.
# Use new=True keyword to start using the new order.
# See documentation of healpy.synalm.
#   category=FutureChangeWarning,
# Sigma is 0.000000 arcmin (0.000000 rad)
# -> fwhm is 0.000000 arcmin
# array([  84.76715559,   60.42235582,   84.34107734, ..., -158.46175089,
#        -155.85593198, -162.02275709])

# %%
import healpy as hp
hp.mollview(healpy.sphtfunc.synfast(cl, 2048), cmap='jet')
# Out:
# /usr/local/lib/python3.7/dist-packages/healpy/sphtfunc.py:400: FutureChangeWarning: The order of the input cl's will change in a future release.
# Use new=True keyword to start using the new order.
# See documentation of healpy.synalm.
#   category=FutureChangeWarning,
# Sigma is 0.000000 arcmin (0.000000 rad)
# -> fwhm is 0.000000 arcmin
