# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd gdrive/MyDrive/
# Out:
# /content/gdrive/MyDrive

# %%
import numpy as np
cl = np.load('./cl_planck_lensed.npy')
ll = cl[:,0]
cl = cl[:,1]

# %%
# !pip install -q 'healpy==1.13.0'
'astropy==4.0'
# Out:
#      |████████████████████████████████| 11.8 MB 247 kB/s
# 'astropy==4.0'

# %%
import matplotlib.pyplot as plt
import healpy as hp
ll = ll[:2000]
cl = cl[:2000]
plt.figure(figsize=(10, 7))
plt.plot(ll, ll * (ll+1) * cl/2*np.pi)
plt.xlabel("$\ell$")
plt.ylabel("$\ell(\ell+1)cl/2*np.pi$")
plt.grid()
hp.write_cl("cl_planck_lensed.npy", cl, overwrite=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/healpy/fitsfunc.py:92: FutureWarning: The default dtype of write_cl() will change in a future version: explicitly set the dtype if it is important to you
#   category=FutureWarning)
